# %%
#for data preprocessing
import pandas as pd

#for matrix math
import numpy as np

#for plotting
import seaborn as sns                #style setting
import matplotlib.pyplot as plt      #graph plotting

#Standardise data value
from sklearn.preprocessing import StandardScaler

# %%
#Load Dataset
sold = pd.read_csv('data/SKU Sold Detail.csv')
sold
# Out:
#      Region  BU_ID        Country  Revenue_Apr21  Margin_Apr21  Revenue_Oct21  \
# 0      AMER     11  United States         265.97        225.20          99.99
# 1      AMER     11  United States          13.08          9.44           0.00
# 2      AMER     11  United States          92.00         79.27          92.00
# 3      AMER     11  United States       77646.33      72910.17       40567.49
# 4      AMER     11  United States         478.85        390.65         464.15
# ...     ...    ...            ...            ...           ...            ...
# 7852   EMEA   6969   South Africa          52.91         15.09          52.91
# 7853   EMEA   6969   South Africa         208.69         68.00         208.69
# 7854   EMEA   6969   South Africa         102.41         29.89         102.41
# 7855   EMEA   6969   South Africa           3.03         -0.50           0.00
# 7856   EMEA   6969   South Africa       76120.80      29984.61       45644.58
#
# ...

# %%
#detect missing value in data frame
sold.isnull().any()
# Out:
# Region           False
# BU_ID            False
# Country          False
# Revenue_Apr21    False
# Margin_Apr21     False
# Revenue_Oct21    False
# Margin_Oct21     False
# Revenue_Jan22    False
# Margin_Jan22     False
# dtype: bool

# %%
numericalData = sold[["Country","Revenue_Apr21","Revenue_Oct21","Revenue_Jan22"]]
numericalData.head()
# Out:
#          Country  Revenue_Apr21  Revenue_Oct21  Revenue_Jan22
# 0  United States         265.97          99.99          99.99
# 1  United States          13.08           0.00           0.00
# 2  United States          92.00          92.00           0.00
# 3  United States       77646.33       40567.49       25413.54
# 4  United States         478.85         464.15         281.57

# %%
#format the figure size to 20rows,10cols
fig, ax = plt.subplots(figsize = (20,10))

#plot graph by Revenue Apr21
plt.subplot(221)
sns.boxplot(x = numericalData["Revenue_Apr21"])
plt.title("Revenue Apr21", fontsize = 20)

#plot graph by Revenue Oct21
plt.subplot(222)
sns.boxplot(x = numericalData["Revenue_Oct21"])
plt.title("Revenue Oct21", fontsize = 20)

#plot graph by Revenue Jan22
plt.subplot(223)
sns.boxplot(x = numericalData["Revenue_Jan22"])
plt.title("Revenue Jan22", fontsize = 20)


plt.tight_layout()
plt.show()

# %%
sorted(numericalData['Revenue_Apr21'])
q1, q3, m= np.percentile(numericalData['Revenue_Apr21'],[25,75,50])
iqr = q3 - q1
lowerb = q1 - (1.5 * iqr)
upperb = q3 + (1.5 * iqr)
print("Apr21 LowerB: ",lowerb)
print("Apr21 Upper B: ",upperb)

median = numericalData.loc[numericalData['Revenue_Apr21']<= upperb,'Revenue_Apr21'].median()
numericalData.loc[numericalData['Revenue_Apr21']> upperb,'Revenue_Apr21'] = np.nan
numericalData.fillna(median,inplace=True)

sorted(numericalData['Revenue_Oct21'])
q1, q3, m= np.percentile(numericalData['Revenue_Oct21'],[25,75,50])
iqr = q3 - q1
lowerb = q1 - (1.5 * iqr)
upperb = q3 + (1.5 * iqr)
print("Oct21 LowerB: ",lowerb)
print("Oct21 Upper B: ",upperb)

median = numericalData.loc[numericalData['Revenue_Oct21']<= upperb,'Revenue_Oct21'].median()
numericalData.loc[numericalData['Revenue_Oct21']> upperb,'Revenue_Oct21'] = np.nan
numericalData.fillna(median,inplace=True)

sorted(numericalData['Revenue_Jan22'])
q1, q3, m= np.percentile(numericalData['Revenue_Jan22'],[25,75,50])
iqr = q3 - q1
lowerb = q1 - (1.5 * iqr)
upperb = q3 + (1.5 * iqr)
print("Jan22 LowerB: ",lowerb)
print("Jan22 Upper B: ",upperb)

median = numericalData.loc[numericalData['Revenue_Jan22']<= upperb,'Revenue_Jan22'].median()
numericalData.loc[numericalData['Revenue_Jan22']> upperb,'Revenue_Jan22'] = np.nan
numericalData.fillna(median,inplace=True)
# Out:
# Apr21 LowerB:  -7193.570000000001
# Apr21 Upper B:  12344.830000000002
# Oct21 LowerB:  -3319.98
# Oct21 Upper B:  5600.34
# Jan22 LowerB:  -734.13
# Jan22 Upper B:  1223.55
# C:\Users\wooi_ling_chin\AppData\Local\Temp\ipykernel_25316\3397859649.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numericalData.fillna(median,inplace=True)
# C:\Users\wooi_ling_chin\AppData\Local\Temp\ipykernel_25316\3397859649.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numericalData.fillna(median,inplace=True)
# C:\Users\wooi_ling_chin\AppData\Local\Temp\ipykernel_25316\3397859649.py:35: SettingWithCopyWarning:
# ...

# %%
numericalData.head()
# Out:
#          Country  Revenue_Apr21  Revenue_Oct21  Revenue_Jan22
# 0  United States         265.97         99.990          99.99
# 1  United States          13.08          0.000           0.00
# 2  United States          92.00         92.000           0.00
# 3  United States         425.31        137.705           0.00
# 4  United States         478.85        464.150         281.57

# %%
#categorical data (those that not in numericalData variable)
categoricalData = sold[["Region","Country"]]

#print
categoricalData.head()
# Out:
#   Region        Country
# 0   AMER  United States
# 1   AMER  United States
# 2   AMER  United States
# 3   AMER  United States
# 4   AMER  United States

# %%
#standardize the numerical data
scaler = StandardScaler()
numericalData.iloc[:,1:] =scaler.fit_transform(numericalData.iloc[:,1:])
# Out:
# C:\Users\wooi_ling_chin\AppData\Local\Temp\ipykernel_25316\1803828919.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numericalData.iloc[:,1:] =scaler.fit_transform(numericalData.iloc[:,1:])

# %%
numericalData.head()
# Out:
#          Country  Revenue_Apr21  Revenue_Oct21  Revenue_Jan22
# 0  United States      -0.483692      -0.456899      -0.012802
# 1  United States      -0.592593      -0.552852      -0.454722
# 2  United States      -0.558608      -0.464566      -0.454722
# 3  United States      -0.415076      -0.420707      -0.454722
# 4  United States      -0.392020      -0.107441       0.789716

# %%
#concatenate the categorical data and numerical data together as nwData
combine = pd.concat([categoricalData,numericalData.iloc[:,1:]],axis=1)
combine.head()
# Out:
#   Region        Country  Revenue_Apr21  Revenue_Oct21  Revenue_Jan22
# 0   AMER  United States      -0.483692      -0.456899      -0.012802
# 1   AMER  United States      -0.592593      -0.552852      -0.454722
# 2   AMER  United States      -0.558608      -0.464566      -0.454722
# 3   AMER  United States      -0.415076      -0.420707      -0.454722
# 4   AMER  United States      -0.392020      -0.107441       0.789716

# %%
combine.describe()
# Out:
#        Revenue_Apr21  Revenue_Oct21  Revenue_Jan22
# count   7.857000e+03   7.857000e+03   7.857000e+03
# mean   -7.325183e-17   3.436506e-17  -1.808687e-17
# std     1.000064e+00   1.000064e+00   1.000064e+00
# min    -5.982256e-01  -5.528521e-01  -4.547220e-01
# 25%    -5.408101e-01  -5.287271e-01  -4.547220e-01
# 50%    -4.150757e-01  -4.207066e-01  -4.547220e-01
# 75%    -1.489846e-02  -3.227357e-02  -1.182992e-01
# max     4.712769e+00   4.807558e+00   4.943557e+00

# %%
#drop the Loan_Status and Loan_ID for x variable that is to be used as the feature selections
#choose the Loan_Status as the y variable that acts as the label
#split the x variable and y variable into test set (30%) and train set (70%)
X = nwData.drop(['Loan_Status','Loan_ID'],axis=1)
y = nwData.loc[:,['Loan_Status']]
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.30,random_state=0)
